# %% [markdown]
# # Model: Decision Tree Regressor
# This notebook documents our process of approaching the given regression task using a DecisionTreeRegressor. The following approaches are documented:
# * paramter optimization using RandomizedSearchCV
# * paramter optimization using Hyperopt
# * each of the mentioned approaches is tried with K-Fold CrossValidation and TimeSeriesSplit CrossValidation

# %%
from sklearn.metrics import mean_squared_error
import data_preprocessing
from sklearn.tree import DecisionTreeRegressor
from hyperopt import hp, space_eval, tpe, fmin, Trials
from math import sqrt
from sklearn.model_selection import RandomizedSearchCV, TimeSeriesSplit
from scipy.stats import uniform, randint
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# %%
# import preprocessed data
train, test = data_preprocessing.preprocess_data("Energy Consumption Dataset.csv")

# %%
# separate features from target variable
def split_x_y(df):
    y = df["Energy Consumption"]
    X = df.drop("Energy Consumption", axis=1)
    return X, y

X_train, y_train = split_x_y(train)
X_test, y_test = split_x_y(test)

# %% [markdown]
# ## Using RandomizedSearchCV
# First, we need to create a search grid / parameter distribution for RandomizedSearchCV to select from

# %%
param_dist = {
    'min_samples_leaf': uniform(),
    'min_samples_split': uniform(),
    'max_depth': randint(2, 18),
    'max_features': randint(1, 18),
    'ccp_alpha': uniform(),
    'max_leaf_nodes': randint(10, 100),
    'min_impurity_decrease': uniform(),
    'min_weight_fraction_leaf': uniform(0.01, 0.5)
}

# %% [markdown]
# ### Using K-Fold CrossVal

# %%
# Create the DT Regressor
reg = DecisionTreeRegressor(random_state=42)
# Create the RandomizedSearchCV instance
random_search = RandomizedSearchCV(reg,
                                   param_distributions=param_dist,
                                   n_iter=1000,
                                   cv=5,
                                   random_state=42,
                                   scoring="neg_mean_squared_error")

# perform the hyperparameter optimization
random_search.fit(X_train, y_train)
# Out:
# c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 100 fits failed out of a total of 5000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5079656210151645 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5036380646574722 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5026836561208673 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5060666581703361 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5060790074116563 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5083484269264884 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5064084194995352 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5051044467938107 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.500571865895911 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5086189499518013 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5058864404896247 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.503668079289773 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5082631543993096 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5029018297251524 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5051425852924706 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5006916671206401 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5005488122567547 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5000027315984085 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5021609894070206 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5091170129143602 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [-1.28114092e+08 -1.42309792e+08 -1.55209933e+08 -1.63415154e+08
#  -1.42309792e+08 -1.63415154e+08 -1.38689985e+08 -1.63415154e+08
#  -1.38689985e+08 -1.33937166e+08 -1.63415154e+08 -1.38350047e+08
#  -1.42025845e+08 -1.40524953e+08 -1.63415154e+08 -1.42025845e+08
#  -1.38566324e+08 -1.40605739e+08 -1.42416060e+08 -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08 -1.33317623e+08
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.39073375e+08 -1.51893180e+08 -1.63415154e+08
#  -1.63415154e+08 -1.62203808e+08 -1.38689985e+08 -1.55209933e+08
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08 -1.32907422e+08
#  -1.33080376e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.42309792e+08 -1.63415154e+08 -1.38449261e+08 -1.33929474e+08
#  -1.38689985e+08 -1.63415154e+08 -1.40605739e+08 -1.55209933e+08
#  -1.38389478e+08 -1.38925167e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08 -1.38925167e+08             nan
#  -1.38389478e+08 -1.39996406e+08 -1.38402440e+08 -1.33068721e+08
#  -1.63415154e+08 -1.38689985e+08 -1.63415154e+08 -1.41395696e+08
#  -1.33415360e+08 -1.36247883e+08 -1.63415154e+08 -1.63415154e+08
#              nan -1.22416766e+08 -1.63415154e+08 -1.38449261e+08
#  -1.33262863e+08 -1.63415154e+08 -1.63415154e+08 -1.57492620e+08
#  -1.63415154e+08 -1.63415154e+08 -1.34515420e+08 -1.63415154e+08
#  -1.63415154e+08 -1.38373314e+08 -1.38689985e+08 -1.42416060e+08
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.38689985e+08 -1.63415154e+08 -1.63415154e+08
#  -1.40566929e+08 -1.63415154e+08 -1.63415154e+08 -1.42025845e+08
#  -1.63415154e+08 -1.33650522e+08 -1.38983500e+08 -1.38402440e+08
#  -1.63415154e+08 -1.63415154e+08 -1.38689985e+08 -1.63415154e+08
#  -1.42416060e+08 -1.63415154e+08 -1.63415154e+08 -1.57141157e+08
#  -1.42309792e+08 -1.57352163e+08 -1.40316571e+08 -1.63415154e+08
#  -1.63415154e+08 -1.55209933e+08 -1.63415154e+08 -1.63415154e+08
#  -1.38402440e+08 -1.42347239e+08 -1.39281562e+08 -1.63415154e+08
#  -1.57525944e+08 -1.38566324e+08 -1.40605739e+08 -1.54097583e+08
#              nan -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08 -1.32620150e+08 -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.57083666e+08 -1.63415154e+08 -1.35274387e+08 -1.63415154e+08
#  -1.39526322e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.56598210e+08 -1.63415154e+08 -1.41705806e+08
#  -1.41395696e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.40605739e+08 -1.63415154e+08 -1.39106799e+08 -1.58173673e+08
#  -1.33428778e+08 -1.42347239e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.33782792e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.33193330e+08 -1.38983500e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.27040597e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08             nan -1.63415154e+08
#  -1.63415154e+08 -1.39073375e+08 -1.56899204e+08 -1.32917925e+08
#  -1.63415154e+08 -1.42025845e+08 -1.63415154e+08 -1.35724362e+08
#  -1.63415154e+08 -1.42309792e+08 -1.56598210e+08 -1.40978772e+08
#  -1.63415154e+08 -1.33413227e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.57563591e+08 -1.39645331e+08 -1.63415154e+08
#  -1.38467847e+08 -1.36262625e+08 -1.63415154e+08 -1.63415154e+08
#  -1.33782792e+08 -1.42416060e+08 -1.63415154e+08 -1.40566864e+08
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.38925167e+08             nan -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08 -1.40734216e+08
#  -1.57122803e+08 -1.63415154e+08             nan -1.38689985e+08
#  -1.63415154e+08 -1.63415154e+08 -1.32645884e+08 -1.63415154e+08
#  -1.38596021e+08 -1.63415154e+08 -1.63415154e+08 -1.40978772e+08
#  -1.39645331e+08 -1.63415154e+08 -1.41705806e+08 -1.27765782e+08
#  -1.42025845e+08 -1.54173780e+08 -1.38925167e+08 -1.38689985e+08
#  -1.39880243e+08 -1.63415154e+08 -1.63415154e+08 -1.35117892e+08
#  -1.38596021e+08 -1.39376986e+08 -1.63415154e+08 -1.36695626e+08
#  -1.40316571e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.40316571e+08 -1.63415154e+08 -1.66280328e+08 -1.38402440e+08
#  -1.63415154e+08 -1.40734216e+08 -1.63415154e+08 -1.63415154e+08
#  -1.42416060e+08 -1.38925167e+08 -1.31846950e+08 -1.33279761e+08
#  -1.40566864e+08 -1.56598210e+08 -1.54590296e+08 -1.63415154e+08
#  -1.51961588e+08 -1.32907422e+08 -1.63415154e+08 -1.40605739e+08
#  -1.33279761e+08 -1.38689985e+08 -1.63415154e+08 -1.63415154e+08
#  -1.38389478e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.56961749e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.57563591e+08 -1.63415154e+08 -1.63415154e+08 -1.39684227e+08
#  -1.38689985e+08 -1.63415154e+08 -1.27897524e+08 -1.38402440e+08
#  -1.63415154e+08 -1.63415154e+08 -1.42416060e+08 -1.37196601e+08
#  -1.63415154e+08 -1.36289749e+08 -1.57750083e+08 -1.52348388e+08
#  -1.41045973e+08 -1.63415154e+08 -1.39996406e+08             nan
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.27621283e+08 -1.63415154e+08 -1.55209933e+08
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08 -1.55371283e+08
#  -1.63415154e+08 -1.55209933e+08 -1.38689985e+08 -1.63415154e+08
#  -1.63415154e+08 -1.33127928e+08 -1.63415154e+08 -1.38925167e+08
#  -1.63415154e+08 -1.63415154e+08 -1.57796074e+08 -1.63415154e+08
#  -1.63415154e+08 -1.48910849e+08 -1.42309792e+08 -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08 -1.39645331e+08 -1.63415154e+08
#  -1.58130353e+08 -1.63415154e+08 -1.38689985e+08 -1.54173225e+08
#  -1.63415154e+08 -1.41158036e+08 -1.63415154e+08 -1.40605739e+08
#  -1.33413227e+08 -1.42309792e+08 -1.63415154e+08 -1.39645331e+08
#  -1.63415154e+08 -1.42347239e+08 -1.39073375e+08 -1.63415154e+08
#  -1.39376986e+08 -1.38621137e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.42591274e+08 -1.55209933e+08 -1.39281562e+08
#  -1.57067485e+08 -1.63415154e+08 -1.33072668e+08             nan
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08 -1.32907422e+08
#  -1.42591274e+08 -1.41705806e+08 -1.63415154e+08             nan
#  -1.34455233e+08 -1.63415154e+08 -1.63415154e+08 -1.39073375e+08
#  -1.63415154e+08 -1.41768631e+08 -1.63415154e+08 -1.39880243e+08
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08 -1.33531291e+08
#  -1.41158036e+08 -1.63415154e+08 -1.38566324e+08 -1.32917925e+08
#  -1.39684227e+08 -1.33279761e+08 -1.39999307e+08 -1.33039122e+08
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.33223680e+08 -1.38389478e+08 -1.63415154e+08 -1.39281562e+08
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08 -1.40061180e+08
#  -1.32586377e+08 -1.63415154e+08 -1.41158036e+08 -1.63415154e+08
#  -1.63415154e+08 -1.39073375e+08 -1.38689985e+08 -1.40978772e+08
#  -1.63415154e+08 -1.39631182e+08 -1.58541743e+08 -1.40566864e+08
#  -1.37196601e+08 -1.33186785e+08 -1.32801964e+08 -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.25725989e+08 -1.63415154e+08 -1.29997928e+08 -1.63415154e+08
#  -1.39376986e+08 -1.63415154e+08 -1.40499694e+08 -1.33710302e+08
#  -1.35137096e+08 -1.63415154e+08 -1.39880243e+08 -1.40524953e+08
#  -1.63415154e+08 -1.41395696e+08 -1.63415154e+08 -1.63415154e+08
#  -1.38467847e+08 -1.38467847e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08 -1.33375319e+08 -1.40061180e+08
#  -1.63415154e+08 -1.63415154e+08 -1.39880243e+08 -1.63415154e+08
#  -1.63415154e+08 -1.52340149e+08 -1.57244497e+08 -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08             nan
#  -1.63415154e+08 -1.63415154e+08 -1.41768631e+08 -1.63415154e+08
#  -1.38925167e+08 -1.63415154e+08 -1.32917925e+08 -1.33413227e+08
#              nan -1.63415154e+08 -1.63415154e+08 -1.41705806e+08
#  -1.63415154e+08 -1.40734216e+08 -1.63415154e+08 -1.40566864e+08
#  -1.63415154e+08 -1.63415154e+08 -1.41705806e+08 -1.63415154e+08
#  -1.33354960e+08 -1.33458801e+08 -1.39376986e+08 -1.63415154e+08
#  -1.63415154e+08 -1.40566864e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.40524953e+08 -1.39228797e+08 -1.32723272e+08
#  -1.42309792e+08 -1.63415154e+08 -1.42309792e+08 -1.42416060e+08
#  -1.63415154e+08 -1.63415154e+08 -1.40316571e+08 -1.63415154e+08
#  -1.63415154e+08 -1.38925167e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08 -1.56932585e+08 -1.33354960e+08
#  -1.38983500e+08 -1.33929474e+08 -1.40605739e+08 -1.39376986e+08
#  -1.57816463e+08 -1.63415154e+08 -1.39999307e+08 -1.38689985e+08
#  -1.63415154e+08 -1.39925177e+08 -1.41705806e+08 -1.63415154e+08
#  -1.63415154e+08 -1.40524953e+08 -1.42025845e+08 -1.63415154e+08
#  -1.39996406e+08 -1.39376986e+08 -1.32806603e+08 -1.38699115e+08
#  -1.39999307e+08 -1.63415154e+08 -1.39073375e+08 -1.38568006e+08
#  -1.63415154e+08 -1.38689985e+08 -1.63415154e+08 -1.57324480e+08
#  -1.63415154e+08 -1.63415154e+08 -1.28193571e+08 -1.63415154e+08
#  -1.37183108e+08 -1.40566864e+08 -1.63415154e+08 -1.63415154e+08
#  -1.57146363e+08 -1.40780039e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.40524953e+08 -1.63415154e+08 -1.40499694e+08
#  -1.36481015e+08             nan -1.63415154e+08 -1.32917925e+08
#  -1.63415154e+08 -1.40112339e+08 -1.33137695e+08 -1.42025845e+08
#  -1.39925177e+08 -1.63415154e+08 -1.38596021e+08 -1.38373314e+08
#  -1.63415154e+08 -1.55209933e+08 -1.63415154e+08 -1.63415154e+08
#  -1.38596021e+08 -1.36262625e+08 -1.63415154e+08 -1.39376986e+08
#  -1.41768631e+08 -1.63415154e+08 -1.63415154e+08 -1.35267933e+08
#  -1.63415154e+08 -1.40734216e+08 -1.57847806e+08 -1.32800243e+08
#  -1.38566324e+08 -1.31002797e+08 -1.36481015e+08 -1.31951017e+08
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08 -1.32649301e+08
#  -1.33223951e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.58131287e+08             nan -1.38402440e+08 -1.39106799e+08
#  -1.32784716e+08 -1.42025845e+08 -1.63415154e+08 -1.33184844e+08
#  -1.32636191e+08 -1.63415154e+08 -1.63415154e+08 -1.55209933e+08
#  -1.38689985e+08 -1.63415154e+08 -1.63415154e+08 -1.33531291e+08
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08 -1.40524953e+08
#  -1.32917925e+08 -1.38373314e+08 -1.35117892e+08 -1.40734216e+08
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.38566324e+08 -1.41705806e+08 -1.63415154e+08 -1.38940000e+08
#  -1.63415154e+08 -1.33438285e+08 -1.38699115e+08 -1.63415154e+08
#  -1.63415154e+08 -1.41768631e+08 -1.63415154e+08 -1.39228797e+08
#  -1.36280109e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.41705806e+08 -1.55209933e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.55209933e+08 -1.40524953e+08 -1.63415154e+08
#  -1.40566929e+08 -1.57071205e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08 -1.57116997e+08 -1.63415154e+08
#  -1.57219681e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.38689985e+08 -1.63415154e+08 -1.42416060e+08 -1.63415154e+08
#  -1.42309792e+08 -1.63415154e+08 -1.63415154e+08 -1.32426985e+08
#  -1.42025845e+08 -1.57352163e+08 -1.38402440e+08 -1.38699115e+08
#  -1.63415154e+08 -1.63415154e+08 -1.33279761e+08 -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08 -1.39376986e+08
#  -1.40734216e+08 -1.63415154e+08 -1.63415154e+08 -1.33458801e+08
#  -1.38689985e+08 -1.38689985e+08 -1.55312400e+08 -1.63415154e+08
#  -1.63415154e+08 -1.40605739e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.26848517e+08 -1.63415154e+08             nan
#  -1.39684227e+08 -1.36393217e+08 -1.39999307e+08 -1.32541276e+08
#  -1.39645331e+08 -1.63415154e+08 -1.33782792e+08 -1.63415154e+08
#  -1.63415154e+08 -1.40734216e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08 -1.42309792e+08 -1.63415154e+08
#  -1.33137695e+08 -1.33199740e+08 -1.41703726e+08 -1.41395696e+08
#  -1.63415154e+08 -1.40734216e+08 -1.63415154e+08 -1.63415154e+08
#  -1.41158036e+08 -1.22163654e+08             nan -1.39925177e+08
#  -1.38596021e+08 -1.40566864e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.38689985e+08 -1.38689985e+08 -1.63415154e+08
#  -1.63415154e+08 -1.38689985e+08 -1.63415154e+08 -1.63415154e+08
#  -1.30725179e+08 -1.33782792e+08 -1.40316571e+08 -1.63415154e+08
#  -1.63415154e+08 -1.41395696e+08 -1.54173780e+08 -1.63415154e+08
#  -1.63415154e+08 -1.41577362e+08 -1.40061180e+08 -1.63415154e+08
#  -1.63415154e+08 -1.39631182e+08 -1.33262863e+08 -1.32917925e+08
#  -1.63415154e+08 -1.39106799e+08 -1.63415154e+08 -1.63415154e+08
#  -1.32917925e+08 -1.41705806e+08 -1.38983500e+08 -1.63415154e+08
#  -1.33080376e+08 -1.38566324e+08 -1.39281562e+08 -1.38925167e+08
#  -1.38402440e+08 -1.58173673e+08 -1.55209933e+08 -1.39880243e+08
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.40605739e+08 -1.25686223e+08 -1.49124607e+08 -1.63415154e+08
#  -1.41395696e+08 -1.63415154e+08 -1.39645331e+08 -1.63415154e+08
#  -1.38689985e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#              nan -1.22600359e+08 -1.52712274e+08 -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08 -1.38699115e+08 -1.33710302e+08
#  -1.40978772e+08 -1.63415154e+08 -1.63415154e+08 -1.41705806e+08
#  -1.28411037e+08 -1.63415154e+08 -1.63415154e+08 -1.53640119e+08
#  -1.38689985e+08 -1.32602368e+08 -1.39880243e+08 -1.41158036e+08
#  -1.63415154e+08 -1.63415154e+08 -1.38925167e+08 -1.51979350e+08
#  -1.32626279e+08 -1.63415154e+08 -1.41705806e+08 -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08 -1.42591274e+08
#  -1.40316571e+08 -1.41158036e+08 -1.63415154e+08 -1.42591274e+08
#  -1.63415154e+08 -1.41705806e+08 -1.35571128e+08 -1.63415154e+08
#  -1.38689985e+08 -1.40524953e+08 -1.55819608e+08 -1.51893180e+08
#  -1.63415154e+08 -1.63415154e+08             nan -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08 -1.41158036e+08 -1.56598210e+08
#  -1.32989566e+08 -1.32426985e+08 -1.63415154e+08 -1.37196601e+08
#  -1.63415154e+08 -1.40316571e+08 -1.63415154e+08 -1.63415154e+08
#  -1.39631182e+08 -1.63415154e+08 -1.32903493e+08 -1.39925177e+08
#  -1.42025845e+08 -1.54964104e+08 -1.63415154e+08 -1.63415154e+08
#  -1.40566864e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.33782792e+08 -1.40524953e+08 -1.38566324e+08 -1.32907422e+08
#              nan -1.38689985e+08 -1.33413227e+08 -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.39999307e+08 -1.38689985e+08 -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08 -1.33068721e+08 -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08 -1.40061180e+08 -1.63415154e+08
#  -1.63415154e+08 -1.40392740e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.31121853e+08 -1.63415154e+08 -1.63415154e+08
#  -1.55182428e+08 -1.32907422e+08 -1.36357878e+08 -1.63415154e+08
#  -1.63415154e+08 -1.38689985e+08 -1.41705806e+08 -1.32917925e+08
#  -1.38689985e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.39073375e+08 -1.63415154e+08 -1.54165411e+08 -1.63415154e+08
#  -1.63415154e+08 -1.33262863e+08 -1.63415154e+08 -1.63415154e+08
#  -1.39073375e+08 -1.40605739e+08 -1.55819608e+08 -1.40734216e+08
#  -1.40061180e+08 -1.57990848e+08 -1.38689985e+08 -1.63415154e+08
#  -1.32835896e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08 -1.38983500e+08 -1.27466858e+08
#  -1.39996406e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08
#  -1.39106799e+08 -1.38467847e+08 -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08 -1.38689985e+08 -1.32755688e+08
#  -1.63415154e+08 -1.40605739e+08 -1.40316571e+08 -1.63415154e+08
#  -1.63415154e+08 -1.40061180e+08 -1.33458801e+08 -1.54244510e+08
#  -1.58173673e+08 -1.41768631e+08 -1.39925177e+08 -1.42025845e+08
#  -1.39645331e+08 -1.57598717e+08 -1.63415154e+08 -1.38925167e+08
#  -1.40524953e+08 -1.39228797e+08 -1.39073375e+08             nan
#  -1.63415154e+08 -1.63415154e+08 -1.40566929e+08 -1.41395696e+08
#  -1.63415154e+08 -1.40566864e+08 -1.63415154e+08 -1.33309332e+08
#  -1.41158036e+08             nan -1.63415154e+08 -1.63415154e+08
#  -1.63415154e+08 -1.63415154e+08 -1.63415154e+08 -1.63415154e+08]
#   warnings.warn(
# RandomizedSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=42),
#                    n_iter=1000,
#                    param_distributions={'ccp_alpha': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001CB1633AA90>,
#                                         'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001CB13AF5690>,
#                                         'max_features': <scipy.stats._distn_infrastructure.rv_dis...
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001CB13AF6A50>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001CB0D077210>,
#                                         'min_weight_fraction_leaf': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001CB16352790>},
#                    random_state=42, scoring='neg_mean_squared_error')

# %%
# inspect the model's performance
best_score = random_search.best_score_
rmse = sqrt(-best_score)
print("RMSE: ", rmse)
print("NRMSE: ", rmse / (y_test.max() - y_test.min()))
# Out:
# RMSE:  11052.766802091313
# NRMSE:  0.1631982813408634

# %%
# inspect the tuned hyperparameters
best_params = random_search.best_params_
best_params
# Out:
# {'ccp_alpha': 0.9954215129254561,
#  'max_depth': 6,
#  'max_features': 7,
#  'max_leaf_nodes': 90,
#  'min_impurity_decrease': 0.8826154575172458,
#  'min_samples_leaf': 0.09697876251609538,
#  'min_samples_split': 0.055706836115245184,
#  'min_weight_fraction_leaf': 0.07461190005137468}

# %%
# Train the model on the whole dataset and predict unseen data to assess it's real performance
rf = DecisionTreeRegressor(**best_params, random_state=42)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
rmse = sqrt(mean_squared_error(y_test, y_pred))
print("RMSE: ", rmse)
print("NRMSE: ", rmse / (y_test.max() - y_test.min()))
# Out:
# RMSE:  11533.000197356256
# NRMSE:  0.17028910901804706

# %%
# Get the feature names as a list
feature_names = list(X_train.columns)

# Plot the Decision Tree
plt.figure(figsize=(40,20))
plot_tree(rf, filled=True, feature_names=feature_names, fontsize=14)
plt.title("Decision Tree Regression", fontsize=20)
plt.show()

# %% [markdown]
# ### Using TimeSeriesSplit

# %%
# Create TimeSeriesSplit instance
tscv = TimeSeriesSplit(n_splits=5)

# %%
# Create the DT Regressor
reg = DecisionTreeRegressor(random_state=42)
# Create the RandomizedSearchCV instance
random_search = RandomizedSearchCV(reg,
                                   param_distributions=param_dist,
                                   n_iter=1000,
                                   cv=tscv, # here, we pass TSCV instead of regular CV
                                   random_state=42,
                                   scoring="neg_mean_squared_error")

# perform the hyperparameter optimization
random_search.fit(X_train, y_train)
# Out:
# c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 100 fits failed out of a total of 5000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5079656210151645 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5036380646574722 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5026836561208673 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5060666581703361 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5060790074116563 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5083484269264884 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5064084194995352 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5051044467938107 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.500571865895911 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5086189499518013 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5058864404896247 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.503668079289773 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5082631543993096 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5029018297251524 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5051425852924706 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5006916671206401 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5005488122567547 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5000027315984085 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5021609894070206 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_weight_fraction_leaf' parameter of DecisionTreeRegressor must be a float in the range [0.0, 0.5]. Got 0.5091170129143602 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Babett\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [-1.29659859e+08 -1.45140415e+08 -1.59659796e+08 -1.68547771e+08
#  -1.45140415e+08 -1.68547771e+08 -1.40909505e+08 -1.68547771e+08
#  -1.41628901e+08 -1.35552974e+08 -1.68547771e+08 -1.41666892e+08
#  -1.44650197e+08 -1.43459597e+08 -1.68547771e+08 -1.44823117e+08
#  -1.41554487e+08 -1.43417988e+08 -1.45140415e+08 -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08 -1.35587768e+08
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.41947428e+08 -1.50354916e+08 -1.68547771e+08
#  -1.68547771e+08 -1.66220039e+08 -1.41705648e+08 -1.59632254e+08
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08 -1.35796483e+08
#  -1.35480056e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.44977317e+08 -1.68547771e+08 -1.41560496e+08 -1.35497569e+08
#  -1.41628901e+08 -1.68547771e+08 -1.43417988e+08 -1.59544955e+08
#  -1.41635001e+08 -1.41873531e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08 -1.41845103e+08             nan
#  -1.41635001e+08 -1.42604716e+08 -1.41554487e+08 -1.35081239e+08
#  -1.68547771e+08 -1.41705648e+08 -1.68547771e+08 -1.44025735e+08
#  -1.34780354e+08 -1.38785823e+08 -1.68547771e+08 -1.68547771e+08
#              nan -1.20095170e+08 -1.68547771e+08 -1.41560496e+08
#  -1.35603133e+08 -1.68547771e+08 -1.68547771e+08 -1.61712847e+08
#  -1.68547771e+08 -1.68547771e+08 -1.40036713e+08 -1.68547771e+08
#  -1.68547771e+08 -1.41577280e+08 -1.41705648e+08 -1.45140415e+08
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.41705648e+08 -1.68547771e+08 -1.68547771e+08
#  -1.43494654e+08 -1.68547771e+08 -1.68547771e+08 -1.44823117e+08
#  -1.68547771e+08 -1.35400530e+08 -1.41925926e+08 -1.41554487e+08
#  -1.68547771e+08 -1.68547771e+08 -1.39647843e+08 -1.68547771e+08
#  -1.45284008e+08 -1.68547771e+08 -1.68547771e+08 -1.61441679e+08
#  -1.44977317e+08 -1.61525794e+08 -1.43258116e+08 -1.68547771e+08
#  -1.68547771e+08 -1.59816402e+08 -1.68547771e+08 -1.68547771e+08
#  -1.41554487e+08 -1.45140415e+08 -1.42097015e+08 -1.68547771e+08
#  -1.61712847e+08 -1.41554487e+08 -1.43417988e+08 -1.59332415e+08
#              nan -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08 -1.34856350e+08 -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.61219889e+08 -1.68547771e+08 -1.37025128e+08 -1.68547771e+08
#  -1.42346997e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.61069703e+08 -1.68547771e+08 -1.44508263e+08
#  -1.44025735e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.43417988e+08 -1.68547771e+08 -1.42097015e+08 -1.62521352e+08
#  -1.35500745e+08 -1.45140415e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.35758121e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.37135113e+08 -1.41925926e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.26662791e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08             nan -1.68547771e+08
#  -1.68547771e+08 -1.42133478e+08 -1.61113564e+08 -1.35048071e+08
#  -1.68547771e+08 -1.44823117e+08 -1.68547771e+08 -1.38480225e+08
#  -1.68547771e+08 -1.45140415e+08 -1.61069703e+08 -1.43775524e+08
#  -1.68547771e+08 -1.35019944e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.61761522e+08 -1.42516427e+08 -1.68547771e+08
#  -1.41701546e+08 -1.38790033e+08 -1.68547771e+08 -1.68547771e+08
#  -1.35552974e+08 -1.45284008e+08 -1.68547771e+08 -1.43596375e+08
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.41845103e+08             nan -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08 -1.43621067e+08
#  -1.61377436e+08 -1.68547771e+08             nan -1.41705648e+08
#  -1.68547771e+08 -1.68547771e+08 -1.34876327e+08 -1.68547771e+08
#  -1.41701546e+08 -1.68547771e+08 -1.68547771e+08 -1.43842517e+08
#  -1.42516427e+08 -1.68547771e+08 -1.44311997e+08 -1.29857872e+08
#  -1.44823117e+08 -1.59375925e+08 -1.41845103e+08 -1.41628901e+08
#  -1.42516427e+08 -1.68547771e+08 -1.68547771e+08 -1.35769829e+08
#  -1.41701546e+08 -1.42301735e+08 -1.68547771e+08 -1.40050076e+08
#  -1.43258116e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.43258116e+08 -1.68547771e+08 -1.68112833e+08 -1.41554487e+08
#  -1.68547771e+08 -1.43596375e+08 -1.68547771e+08 -1.68547771e+08
#  -1.45284008e+08 -1.41873531e+08 -1.34967706e+08 -1.34433033e+08
#  -1.43596375e+08 -1.61069703e+08 -1.59375925e+08 -1.68547771e+08
#  -1.62542512e+08 -1.35796483e+08 -1.68547771e+08 -1.43417988e+08
#  -1.34433033e+08 -1.41628901e+08 -1.68547771e+08 -1.68547771e+08
#  -1.41635001e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.61282573e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.61771270e+08 -1.68547771e+08 -1.68547771e+08 -1.42516427e+08
#  -1.41705648e+08 -1.68547771e+08 -1.29232777e+08 -1.41560496e+08
#  -1.68547771e+08 -1.68547771e+08 -1.45284008e+08 -1.38190117e+08
#  -1.68547771e+08 -1.39102979e+08 -1.61912228e+08 -1.59087814e+08
#  -1.43870366e+08 -1.68547771e+08 -1.42604716e+08             nan
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.26825547e+08 -1.68547771e+08 -1.60129665e+08
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08 -1.60194089e+08
#  -1.68547771e+08 -1.59544955e+08 -1.41705648e+08 -1.68547771e+08
#  -1.68547771e+08 -1.35460212e+08 -1.68547771e+08 -1.41873531e+08
#  -1.68547771e+08 -1.68547771e+08 -1.61938614e+08 -1.68547771e+08
#  -1.68547771e+08 -1.46264999e+08 -1.44986446e+08 -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08 -1.42516427e+08 -1.68547771e+08
#  -1.62399843e+08 -1.68547771e+08 -1.41705648e+08 -1.59356560e+08
#  -1.68547771e+08 -1.43870366e+08 -1.68547771e+08 -1.43417988e+08
#  -1.35019944e+08 -1.45140415e+08 -1.68547771e+08 -1.42346997e+08
#  -1.68547771e+08 -1.45140415e+08 -1.42133478e+08 -1.68547771e+08
#  -1.42301735e+08 -1.41701546e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.46264999e+08 -1.59641964e+08 -1.42097015e+08
#  -1.61235675e+08 -1.68547771e+08 -1.35480056e+08             nan
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08 -1.35796483e+08
#  -1.50338336e+08 -1.44311997e+08 -1.68547771e+08             nan
#  -1.34856350e+08 -1.68547771e+08 -1.68547771e+08 -1.41947428e+08
#  -1.68547771e+08 -1.44650197e+08 -1.68547771e+08 -1.42516427e+08
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08 -1.35225092e+08
#  -1.44025735e+08 -1.68547771e+08 -1.41554487e+08 -1.35048071e+08
#  -1.42516427e+08 -1.38595929e+08 -1.42609686e+08 -1.35093203e+08
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.35257168e+08 -1.41635001e+08 -1.68547771e+08 -1.42097015e+08
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08 -1.42716787e+08
#  -1.34491144e+08 -1.68547771e+08 -1.44025735e+08 -1.68547771e+08
#  -1.68547771e+08 -1.41947428e+08 -1.41705648e+08 -1.43842517e+08
#  -1.68547771e+08 -1.42516427e+08 -1.63150498e+08 -1.43596375e+08
#  -1.38257273e+08 -1.35292247e+08 -1.35219773e+08 -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.29203282e+08 -1.68547771e+08 -1.31245562e+08 -1.68547771e+08
#  -1.42153459e+08 -1.68547771e+08 -1.43258116e+08 -1.35552974e+08
#  -1.39946549e+08 -1.68547771e+08 -1.42552812e+08 -1.43535501e+08
#  -1.68547771e+08 -1.44180834e+08 -1.68547771e+08 -1.68547771e+08
#  -1.41701546e+08 -1.41701546e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08 -1.34975038e+08 -1.42716787e+08
#  -1.68547771e+08 -1.68547771e+08 -1.42508349e+08 -1.68547771e+08
#  -1.68547771e+08 -1.62998401e+08 -1.61524435e+08 -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08             nan
#  -1.68547771e+08 -1.68547771e+08 -1.44650197e+08 -1.68547771e+08
#  -1.41873531e+08 -1.68547771e+08 -1.35103932e+08 -1.35019944e+08
#              nan -1.68547771e+08 -1.68547771e+08 -1.44508263e+08
#  -1.68547771e+08 -1.43596375e+08 -1.68547771e+08 -1.43535501e+08
#  -1.68547771e+08 -1.68547771e+08 -1.44508263e+08 -1.68547771e+08
#  -1.35601329e+08 -1.35225092e+08 -1.42153459e+08 -1.68547771e+08
#  -1.68547771e+08 -1.43535501e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.43494654e+08 -1.42097015e+08 -1.34575223e+08
#  -1.45140415e+08 -1.68547771e+08 -1.45140415e+08 -1.45284008e+08
#  -1.68547771e+08 -1.68547771e+08 -1.43258116e+08 -1.68547771e+08
#  -1.68547771e+08 -1.41873531e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08 -1.61218183e+08 -1.35601329e+08
#  -1.41925926e+08 -1.35400530e+08 -1.43494654e+08 -1.42346997e+08
#  -1.61917136e+08 -1.68547771e+08 -1.42608211e+08 -1.41554487e+08
#  -1.68547771e+08 -1.42604716e+08 -1.44311997e+08 -1.68547771e+08
#  -1.68547771e+08 -1.43459597e+08 -1.44823117e+08 -1.68547771e+08
#  -1.42604716e+08 -1.42301735e+08 -1.35502126e+08 -1.41750655e+08
#  -1.42608211e+08 -1.68547771e+08 -1.42133478e+08 -1.41534764e+08
#  -1.68547771e+08 -1.41705648e+08 -1.68547771e+08 -1.61525794e+08
#  -1.68547771e+08 -1.68547771e+08 -1.29128107e+08 -1.68547771e+08
#  -1.37728633e+08 -1.43596375e+08 -1.68547771e+08 -1.68547771e+08
#  -1.61461955e+08 -1.43775524e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.43494654e+08 -1.68547771e+08 -1.43258116e+08
#  -1.38931918e+08             nan -1.68547771e+08 -1.35048071e+08
#  -1.68547771e+08 -1.42997026e+08 -1.35460212e+08 -1.44823117e+08
#  -1.42604716e+08 -1.68547771e+08 -1.41701546e+08 -1.41577280e+08
#  -1.68547771e+08 -1.59544955e+08 -1.68547771e+08 -1.68547771e+08
#  -1.41701546e+08 -1.39058498e+08 -1.68547771e+08 -1.42153459e+08
#  -1.44650197e+08 -1.68547771e+08 -1.68547771e+08 -1.38147948e+08
#  -1.68547771e+08 -1.43775524e+08 -1.61918968e+08 -1.35190535e+08
#  -1.41554487e+08 -1.34967706e+08 -1.36953165e+08 -1.35500736e+08
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08 -1.31600361e+08
#  -1.35469295e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.62399843e+08             nan -1.41554487e+08 -1.42133478e+08
#  -1.34962807e+08 -1.44823117e+08 -1.68547771e+08 -1.35509941e+08
#  -1.34969134e+08 -1.68547771e+08 -1.68547771e+08 -1.59641964e+08
#  -1.41705648e+08 -1.68547771e+08 -1.68547771e+08 -1.35225092e+08
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08 -1.43535501e+08
#  -1.35048071e+08 -1.41577280e+08 -1.35823448e+08 -1.43596375e+08
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.41554487e+08 -1.44472920e+08 -1.68547771e+08 -1.41925926e+08
#  -1.68547771e+08 -1.35615351e+08 -1.41750655e+08 -1.68547771e+08
#  -1.68547771e+08 -1.44508263e+08 -1.68547771e+08 -1.42097015e+08
#  -1.38798029e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.44508263e+08 -1.59544955e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.59640079e+08 -1.43535501e+08 -1.68547771e+08
#  -1.43494654e+08 -1.61461955e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08 -1.61372349e+08 -1.68547771e+08
#  -1.61524435e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.41705648e+08 -1.68547771e+08 -1.45284008e+08 -1.68547771e+08
#  -1.45140415e+08 -1.68547771e+08 -1.68547771e+08 -1.33087300e+08
#  -1.44823117e+08 -1.61525794e+08 -1.41560496e+08 -1.41750655e+08
#  -1.68547771e+08 -1.68547771e+08 -1.34417478e+08 -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08 -1.42153459e+08
#  -1.43596375e+08 -1.68547771e+08 -1.68547771e+08 -1.34975038e+08
#  -1.41628901e+08 -1.41705648e+08 -1.60103900e+08 -1.68547771e+08
#  -1.68547771e+08 -1.43417988e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.29309648e+08 -1.68547771e+08             nan
#  -1.42516427e+08 -1.39046114e+08 -1.42609686e+08 -1.34743412e+08
#  -1.42346997e+08 -1.68547771e+08 -1.35552974e+08 -1.68547771e+08
#  -1.68547771e+08 -1.43596375e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08 -1.45140415e+08 -1.68547771e+08
#  -1.35460212e+08 -1.35509941e+08 -1.44508263e+08 -1.44180834e+08
#  -1.68547771e+08 -1.43621067e+08 -1.68547771e+08 -1.68547771e+08
#  -1.44025735e+08 -1.24355161e+08             nan -1.42604716e+08
#  -1.41701546e+08 -1.43535501e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.41705648e+08 -1.41628901e+08 -1.68547771e+08
#  -1.68547771e+08 -1.41705648e+08 -1.68547771e+08 -1.68547771e+08
#  -1.30488236e+08 -1.35552974e+08 -1.42997026e+08 -1.68547771e+08
#  -1.68547771e+08 -1.44025735e+08 -1.58398202e+08 -1.68547771e+08
#  -1.68547771e+08 -1.44311997e+08 -1.42866235e+08 -1.68547771e+08
#  -1.68547771e+08 -1.42516427e+08 -1.35460212e+08 -1.35048071e+08
#  -1.68547771e+08 -1.42083343e+08 -1.68547771e+08 -1.68547771e+08
#  -1.35048071e+08 -1.44311997e+08 -1.41925926e+08 -1.68547771e+08
#  -1.35496201e+08 -1.41554487e+08 -1.42097015e+08 -1.41873531e+08
#  -1.41554487e+08 -1.62542512e+08 -1.59654193e+08 -1.42508349e+08
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.43417988e+08 -1.25069857e+08 -1.54761957e+08 -1.68547771e+08
#  -1.44025735e+08 -1.68547771e+08 -1.42516427e+08 -1.68547771e+08
#  -1.41705648e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#              nan -1.21997278e+08 -1.59087814e+08 -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08 -1.41750655e+08 -1.35758121e+08
#  -1.43775524e+08 -1.68547771e+08 -1.68547771e+08 -1.44508263e+08
#  -1.29668733e+08 -1.68547771e+08 -1.68547771e+08 -1.57287777e+08
#  -1.41705648e+08 -1.32512563e+08 -1.42508349e+08 -1.43870366e+08
#  -1.68547771e+08 -1.68547771e+08 -1.41845103e+08 -1.50354916e+08
#  -1.34986522e+08 -1.68547771e+08 -1.44311997e+08 -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08 -1.45563421e+08
#  -1.43258116e+08 -1.44025735e+08 -1.68547771e+08 -1.45563421e+08
#  -1.68547771e+08 -1.44472920e+08 -1.37076792e+08 -1.68547771e+08
#  -1.39585420e+08 -1.43535501e+08 -1.62918714e+08 -1.50814769e+08
#  -1.68547771e+08 -1.68547771e+08             nan -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08 -1.44025735e+08 -1.61069703e+08
#  -1.35407986e+08 -1.32854625e+08 -1.68547771e+08 -1.38268314e+08
#  -1.68547771e+08 -1.43258116e+08 -1.68547771e+08 -1.68547771e+08
#  -1.42516427e+08 -1.68547771e+08 -1.35099157e+08 -1.42604716e+08
#  -1.44823117e+08 -1.59572396e+08 -1.68547771e+08 -1.68547771e+08
#  -1.43535501e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.35758121e+08 -1.43494654e+08 -1.41554487e+08 -1.35469040e+08
#              nan -1.41705648e+08 -1.35019944e+08 -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.42604716e+08 -1.41628901e+08 -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08 -1.35082321e+08 -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08 -1.42716787e+08 -1.68547771e+08
#  -1.68547771e+08 -1.43258116e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.32774469e+08 -1.68547771e+08 -1.68547771e+08
#  -1.60253560e+08 -1.35796483e+08 -1.39148310e+08 -1.68547771e+08
#  -1.68547771e+08 -1.41705648e+08 -1.44472920e+08 -1.34962807e+08
#  -1.39841756e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.42133478e+08 -1.68547771e+08 -1.58415443e+08 -1.68547771e+08
#  -1.68547771e+08 -1.35460212e+08 -1.68547771e+08 -1.68547771e+08
#  -1.42133478e+08 -1.43417988e+08 -1.63150498e+08 -1.43596375e+08
#  -1.42716787e+08 -1.62163021e+08 -1.41705648e+08 -1.68547771e+08
#  -1.35103907e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08 -1.41925926e+08 -1.25704225e+08
#  -1.42604716e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08
#  -1.42097015e+08 -1.41693658e+08 -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08 -1.41628901e+08 -1.34967706e+08
#  -1.68547771e+08 -1.43417988e+08 -1.43258116e+08 -1.68547771e+08
#  -1.68547771e+08 -1.42716787e+08 -1.34988607e+08 -1.59374682e+08
#  -1.62521352e+08 -1.44650197e+08 -1.42604716e+08 -1.44650197e+08
#  -1.42516427e+08 -1.61789290e+08 -1.68547771e+08 -1.41845103e+08
#  -1.43535501e+08 -1.42097015e+08 -1.41947428e+08             nan
#  -1.68547771e+08 -1.68547771e+08 -1.43494654e+08 -1.44180834e+08
#  -1.68547771e+08 -1.43535501e+08 -1.68547771e+08 -1.35502249e+08
#  -1.44025735e+08             nan -1.68547771e+08 -1.68547771e+08
#  -1.68547771e+08 -1.68547771e+08 -1.68547771e+08 -1.68547771e+08]
#   warnings.warn(
# RandomizedSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None),
#                    estimator=DecisionTreeRegressor(random_state=42),
#                    n_iter=1000,
#                    param_distributions={'ccp_alpha': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001CB1633AA90>,
#                                         'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001C...
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001CB13AF6A50>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001CB0D077210>,
#                                         'min_weight_fraction_leaf': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001CB16352790>},
#                    random_state=42, scoring='neg_mean_squared_error')

# %%
# inspect the model's performance
best_score = random_search.best_score_
rmse = sqrt(-best_score)
print("RMSE: ", rmse)
print("NRMSE: ", rmse / (y_test.max() - y_test.min()))
# Out:
# RMSE:  10958.794202509443
# NRMSE:  0.16181074037311288

# %%
# inspect the tuned hyperparameters
best_params = random_search.best_params_
best_params
# Out:
# {'ccp_alpha': 0.15041689110352818,
#  'max_depth': 6,
#  'max_features': 17,
#  'max_leaf_nodes': 86,
#  'min_impurity_decrease': 0.06351182959000135,
#  'min_samples_leaf': 0.03682186763599138,
#  'min_samples_split': 0.1338521188006332,
#  'min_weight_fraction_leaf': 0.016835982413498644}

# %%
# Train the model on the whole dataset and predict unseen data to assess it's real performance
rf = DecisionTreeRegressor(**best_params, random_state=42)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
rmse = sqrt(mean_squared_error(y_test, y_pred))
print("RMSE: ", rmse)
print("NRMSE: ", rmse / (y_test.max() - y_test.min()))
# Out:
# RMSE:  11093.479600694762
# NRMSE:  0.1637994212074353

# %%
# Get the feature names as a list
feature_names = list(X_train.columns)

# Plot the Decision Tree
plt.figure(figsize=(40,20))
plot_tree(rf, filled=True, feature_names=feature_names, fontsize=12)
plt.title("Decision Tree Regression")
plt.show()

# %% [markdown]
# ## Using Hyperopt

# %%
from hyperopt import hp, space_eval, tpe, fmin, Trials
from sklearn.model_selection import cross_val_score

# %% [markdown]
# The following functions are passed to Hyperopt's `fmin` func - one using K-Fold CV and one using TimeSeriesSplit

# %%
# optimization function for K-Fold Cross Validation
def decision_tree_regressor_kfold(args):
    min_samples_leaf, min_samples_split, max_depth, max_features, ccp_alpha, max_leaf_nodes, min_impurity_decrease, min_weight_fraction_leaf = args

    reg = DecisionTreeRegressor(random_state=42,

                                min_samples_leaf=min_samples_leaf,
                                min_samples_split=min_samples_split,
                                ccp_alpha=ccp_alpha,
                                min_impurity_decrease=min_impurity_decrease,
                                min_weight_fraction_leaf=min_weight_fraction_leaf,

                                max_depth=int(max_depth),
                                max_features=int(max_features),
                                max_leaf_nodes=int(max_leaf_nodes),
                               )

    # we return the best score resulting from cross validation - KF-fold here
    return sqrt(-cross_val_score(reg, X_train, y_train, cv=5, scoring="neg_mean_squared_error", n_jobs=-1).mean())

# %%
# optimization function for TimeSeriesSplit Cross Validation
def decision_tree_regressor_tscv(args):
    min_samples_leaf, min_samples_split, max_depth, max_features, ccp_alpha, max_leaf_nodes, min_impurity_decrease, min_weight_fraction_leaf = args

    tscv = TimeSeriesSplit(n_splits=5)

    reg = DecisionTreeRegressor(random_state=42,

                                min_samples_leaf=min_samples_leaf,
                                min_samples_split=min_samples_split,
                                ccp_alpha=ccp_alpha,
                                min_impurity_decrease=min_impurity_decrease,
                                min_weight_fraction_leaf=min_weight_fraction_leaf,

                                max_depth=int(max_depth),
                                max_features=int(max_features),
                                max_leaf_nodes=int(max_leaf_nodes),
                               )

    # we return the best score resulting from cross validation - TimeSeriesSplit here
    return sqrt(-cross_val_score(reg, X_train, y_train, cv=tscv, scoring="neg_mean_squared_error", n_jobs=-1).mean())

# %%
# define the search space
space = [
    hp.uniform('min_samples_leaf', 0.01, 1.0),
    hp.uniform('min_samples_split', 0.01, 1.0),
    hp.quniform('max_depth', 2, 18, 1),
    hp.quniform('max_features', 1, 18, 2),
    hp.quniform('ccp_alpha', 0.01, 1.0, 0.05),
    hp.quniform('max_leaf_nodes', 10, 100, 5),
    hp.quniform('min_impurity_decrease', 0.01, 1.0, 0.05),
    hp.quniform('min_weight_fraction_leaf', 0.01, 0.5, 0.05)
]

# %% [markdown]
# ### Using regular K-Fold CV

# %%
trials = Trials()

# to perform a hyperparameter optimization, we pass the optimization function to Hyperopt
# Here, we're using K-Fold CV
best = fmin(fn=decision_tree_regressor_kfold, space=space, algo=tpe.suggest, verbose=True, max_evals=1000, trials=trials)
# Out:
#   0%|          | 0/1000 [00:00<?, ?trial/s, best loss=?]
# 100%|██████████| 1000/1000 [07:06<00:00,  2.34trial/s, best loss: 10539.866242017864]

# %%
# inspect the model's performance
rmse = trials.best_trial['result']['loss']
print("RMSE: ", rmse)
print("NRMSE: ", rmse / (y_test.max() - y_test.min()))
# Out:
# RMSE:  10539.866242017864
# NRMSE:  0.1556251106224768

# %%
# inspect the tuned hyperparameters
best
# Out:
# {'ccp_alpha': 0.35000000000000003,
#  'max_depth': 10.0,
#  'max_features': 14.0,
#  'max_leaf_nodes': 70.0,
#  'min_impurity_decrease': 0.35000000000000003,
#  'min_samples_leaf': 0.010303571434540866,
#  'min_samples_split': 0.02778523343677496,
#  'min_weight_fraction_leaf': 0.0}

# %%
# Train the model on the whole dataset and predict unseen data to assess it's real performance

# get optimized hyperparameters from result
ccp_alpha, max_depth, max_features, max_leaf_nodes, min_impurity_decrease, min_samples_leaf, min_samples_split, min_weight_fraction_leaf = best.values()

# train the Decision Tree
reg = DecisionTreeRegressor(random_state=42,

                            min_samples_leaf=min_samples_leaf,
                            min_samples_split=min_samples_split,
                            ccp_alpha=ccp_alpha,
                            min_impurity_decrease=min_impurity_decrease,
                            min_weight_fraction_leaf=min_weight_fraction_leaf,

                            max_depth=int(max_depth),
                            max_features=int(max_features),
                            max_leaf_nodes=int(max_leaf_nodes))

# predict on whole dataset
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
rmse = sqrt(mean_squared_error(y_test, y_pred))
print("RMSE: ", rmse)
print("NRMSE: ", rmse / (y_test.max() - y_test.min()))
# Out:
# RMSE:  11093.479600694762
# NRMSE:  0.1637994212074353

# %%
# Get the feature names as a list
feature_names = list(X_train.columns)

# Plot the Decision Tree
plt.figure(figsize=(40,20))
plot_tree(rf, filled=True, feature_names=feature_names, fontsize=12)
plt.title("Decision Tree Regression")
plt.show()

# %% [markdown]
# ### using TimeSeriesSplit

# %%
trials = Trials()

# to perform a hyperparameter optimization, we pass the optimization function to Hyperopt
# Here, we're using K-Fold CV
best = fmin(fn=decision_tree_regressor_tscv, space=space, algo=tpe.suggest, verbose=True, max_evals=1000, trials=trials)
# Out:
#   0%|          | 0/1000 [00:00<?, ?trial/s, best loss=?]
# 100%|██████████| 1000/1000 [06:42<00:00,  2.49trial/s, best loss: 10599.187344643638]

# %%
# inspect the model's performance
rmse = trials.best_trial['result']['loss']
print("RMSE: ", rmse)
print("NRMSE: ", rmse / (y_test.max() - y_test.min()))
# Out:
# RMSE:  10599.187344643638
# NRMSE:  0.15650100913450726

# %%
# inspect the tuned hyperparameters
best
# Out:
# {'ccp_alpha': 0.0,
#  'max_depth': 17.0,
#  'max_features': 14.0,
#  'max_leaf_nodes': 60.0,
#  'min_impurity_decrease': 0.35000000000000003,
#  'min_samples_leaf': 0.011516188812267238,
#  'min_samples_split': 0.01090106605907824,
#  'min_weight_fraction_leaf': 0.0}

# %%
# Train the model on the whole dataset and predict unseen data to assess it's real performance

# get optimized hyperparameters from result
ccp_alpha, max_depth, max_features, max_leaf_nodes, min_impurity_decrease, min_samples_leaf, min_samples_split, min_weight_fraction_leaf = best.values()

# train the Decision Tree
reg = DecisionTreeRegressor(random_state=42,

                            min_samples_leaf=min_samples_leaf,
                            min_samples_split=min_samples_split,
                            ccp_alpha=ccp_alpha,
                            min_impurity_decrease=min_impurity_decrease,
                            min_weight_fraction_leaf=min_weight_fraction_leaf,

                            max_depth=int(max_depth),
                            max_features=int(max_features),
                            max_leaf_nodes=int(max_leaf_nodes))

# predict on whole dataset
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
rmse = sqrt(mean_squared_error(y_test, y_pred))
print("RMSE: ", rmse)
print("NRMSE: ", rmse / (y_test.max() - y_test.min()))
# Out:
# RMSE:  11093.479600694762
# NRMSE:  0.1637994212074353

# %%
# Get the feature names as a list
feature_names = list(X_train.columns)

# Plot the Decision Tree
plt.figure(figsize=(45,20))
plot_tree(rf, filled=True, feature_names=feature_names, fontsize=14)
plt.title("Decision Tree Regression")
plt.show()
